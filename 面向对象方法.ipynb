# %%
class MyClass:
    '''这是一个简单的类实例'''
    i=12345
    def f(self):
        return 'hello world'
x=MyClass()
print("myclass类的属性i为：",x.i)
print('myckass类的方法f输出为',x.f())
# Out:
# myclass类的属性i为： 12345
# myckass类的方法f输出为 hello world
